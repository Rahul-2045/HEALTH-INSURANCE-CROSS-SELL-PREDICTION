# %% [markdown]
# <a href="https://colab.research.google.com/github/Rahulverma2045/HEALTH-INSURANCE-CROSS-SELL-PREDICTION/blob/main/Copy_of_Sample_ML_Submission_Template.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    - HEALTH INSURANCE CROSS SELL PREDICTION

# %% [markdown]
# #  **Project Type**    - Classification
# # **Contribution**    - Team
# # **Team Member 1 -** RAHUL VERMA
# # **Team Member 2 -** SUMIT SHARMA
# # **Team Member 3 -** KHUSHBOO KHANARAH
# # **Team Member 4 -** VISHAL TOMAR

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Write the summary here within 500-600 words.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 15 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]
#
# 6. You may add more ml algorithms for model creation. Make sure for each and every algorithm, the following format should be answered.
#
#
# *   Explain the ML Model used and it's performance using Evaluation metric Score Chart.
#
#
# *   Cross- Validation & Hyperparameter Tuning
#
# *   Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.
#
# *   Explain each evaluation metric's indication towards business and the business impact pf the ML model used.

# %% [markdown]
# # **Problem Statement**
#
#
#
# # Our client is an Insurance company that has provided Health Insurance to its customers now they need your help in building a model to predict whether the policyholders (customers) from past year will also be interested in Vehicle Insurance provided by the company.
#
# # An insurance policy is an arrangement by which a company undertakes to provide a guarantee of compensation for specified loss, damage, illness, or death in return for the payment of a specified premium. A premium is a sum of money that the customer needs to pay regularly to an insurance company for this guarantee.
#
# # For example, you may pay a premium of Rs. 5000 each year for a health insurance cover of Rs. 200,000/- so that if, God forbid, you fall ill and need to be hospitalised in that year, the insurance provider company will bear the cost of hospitalisation etc. for upto Rs. 200,000. Now if you are wondering how can company bear such high hospitalisation cost when it charges a premium of only Rs. 5000/-, that is where the concept of probabilities comes in picture. For example, like you, there may be 100 customers who would be paying a premium of Rs. 5000 every year, but only a few of them (say 2-3) would get hospitalised that year and not everyone. This way everyone shares the risk of everyone else.
#
# # Just like medical insurance, there is vehicle insurance where every year customer needs to pay a premium of certain amount to insurance provider company so that in case of unfortunate accident by the vehicle, the insurance provider company will provide a compensation (called ‘sum assured’) to the customer.
#
# # Building a model to predict whether a customer would be interested in Vehicle Insurance is extremely helpful for the company because it can then accordingly plan its communication strategy to reach out to those customers and optimise its business model and revenue.
#
# # Now, in order to predict, whether the customer would be interested in Vehicle insurance, you have information about demographics (gender, age, region code type), Vehicles (Vehicle Age, Damage), Policy (Premium, sourcing channel) etc.

# %% [markdown]
# # **Attribute Information**

# %% [markdown]
# #1. id :	Unique ID for the customer
#
# #2. Gender	: Gender of the customer
#
# #3. Age :	Age of the customer
#
# #4. Driving_License	0 : Customer does not have DL, 1 : Customer already has DL
#
# #5. Region_Code :	Unique code for the region of the customer
#
# #6. Previously_Insured	: 1 : Customer already has Vehicle Insurance, 0 : Customer doesn't have Vehicle Insurance
#
# #7. Vehicle_Age :	Age of the Vehicle
#
# #8. Vehicle_Damage	 :1 : Customer got his/her vehicle damaged in the past. 0 : Customer didn't get his/her vehicle damaged in the past.
#
# #9. Annual_Premium	: The amount customer needs to pay as premium in the year
#
# #10. PolicySalesChannel :	Anonymized Code for the channel of outreaching to the customer ie. Different Agents, Over Mail, Over Phone, In Person, etc.
#
# #11. Vintage :	Number of Days, Customer has been associated with the company
#
# #12. Response :	1 : Customer is interested, 0 : Customer is not interested

# %% [markdown]
# ## **A Quick overview of our strategy:**
# This project is divided into multiple sections and each section will have its own importance to our problem statement. the approach that we will be following in this project is given as-
#
# Section 1: Data overview: In this section, we will be importing important libraries and simply loading our dataset into google collab and will explore the basic information about the data.
#
# Section 2: Exploratory Data Analysis: In this section, We will focus on Exploratory data analysis of the dataset using various methods and visualization plots and will be extracting the information from this dataset as much as we can.
#
# Section 3: Outliers handling: In this section, we will be dealing with outliers in our dataset and will see how to define our outlier criteria and deal with outliers.
#
# Section 4: Feature Engineering: In this Section, we will be splitting the data into training and testing datasets then we will be scaling the data.
# Section 6: Model implementation: In this section, we will be applying and evaluating the ML models to predict the results.
#
# Section 7: Model Explainability: In this section, we will use model explainability to explain the results.
#
# Section 8: In this section, we will be giving a quick summary of the entire notebook.

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Importing important libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

from sklearn.model_selection import train_test_split , GridSearchCV, RandomizedSearchCV
from sklearn.metrics import confusion_matrix,classification_report,plot_confusion_matrix
from sklearn.metrics import plot_precision_recall_curve,plot_roc_curve

from sklearn.preprocessing import StandardScaler, OneHotEncoder, LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from collections import Counter

# %% [markdown]
# ### Dataset Loading

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
# importing the original dataset and saving it as initial_df
initial_df  =  pd.read_csv('/content/drive/MyDrive/TRAIN-HEALTH INSURANCE CROSS SELL PREDICTION.csv')

# %%
# creating a copy of the given data and naming it as df
df = initial_df.copy()

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# exploring first 5 rows
df.head()
# Out:
#    id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0   1    Male   44                1         28.0                   0
# 1   2    Male   76                1          3.0                   0
# 2   3    Male   47                1         28.0                   0
# 3   4    Male   21                1         11.0                   1
# 4   5  Female   29                1         41.0                   1
#
#   Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  \
# 0   > 2 Years            Yes         40454.0                  26.0      217
# 1    1-2 Year             No         33536.0                  26.0      183
# 2   > 2 Years            Yes         38294.0                  26.0       27
# 3    < 1 Year             No         28619.0                 152.0      203
# 4    < 1 Year             No         27496.0                 152.0       39
#
#    Response
# 0         1
# 1         0
# 2         1
# 3         0
# 4         0

# %% [markdown]
# ### Dataset Information

# %%
 # getting basic information
 df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 381109 entries, 0 to 381108
# Data columns (total 12 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id                    381109 non-null  int64
#  1   Gender                381109 non-null  object
#  2   Age                   381109 non-null  int64
#  3   Driving_License       381109 non-null  int64
#  4   Region_Code           381109 non-null  float64
#  5   Previously_Insured    381109 non-null  int64
#  6   Vehicle_Age           381109 non-null  object
#  7   Vehicle_Damage        381109 non-null  object
#  8   Annual_Premium        381109 non-null  float64
#  9   Policy_Sales_Channel  381109 non-null  float64
#  10  Vintage               381109 non-null  int64
#  11  Response              381109 non-null  int64
# dtypes: float64(3), int64(6), object(3)
# memory usage: 34.9+ MB

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
# Check for duplicated entries.
print("Duplicate entry in df:",len(df[df.duplicated()]))
# Out:
# Duplicate entry in df: 0

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
# checking for null values
df.isnull().sum()
# Out:
# id                      0
# Gender                  0
# Age                     0
# Driving_License         0
# Region_Code             0
# Previously_Insured      0
# Vehicle_Age             0
# Vehicle_Damage          0
# Annual_Premium          0
# Policy_Sales_Channel    0
# Vintage                 0
# Response                0
# dtype: int64

# %%
# Visualizing the missing values
plt.figure(figsize=(14, 5))
sns.heatmap(df.isnull(), cbar=True, yticklabels=False)
plt.xlabel("column_name", size=14, weight="bold")
plt.title("missing values in column",fontweight="bold",size=17)
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# Answer Here

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
pd.options.display.float_format = '{:,.2f} %'.format
print((df.isnull().sum()/len(df))*100)
pd.options.display.float_format = '{:,.2f}'.format
# Out:
# id                     0.00 %
# Gender                 0.00 %
# Age                    0.00 %
# Driving_License        0.00 %
# Region_Code            0.00 %
# Previously_Insured     0.00 %
# Vehicle_Age            0.00 %
# Vehicle_Damage         0.00 %
# Annual_Premium         0.00 %
# Policy_Sales_Channel   0.00 %
# Vintage                0.00 %
# Response               0.00 %
# dtype: float64

# %%
# Dataset Describe
df.describe().style.background_gradient()
# Out:
# <style type="text/css">
# #T_685ac_row0_col0, #T_685ac_row0_col1, #T_685ac_row0_col2, #T_685ac_row0_col3, #T_685ac_row0_col4, #T_685ac_row0_col6, #T_685ac_row0_col7, #T_685ac_row0_col8, #T_685ac_row7_col0, #T_685ac_row7_col5 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_685ac_row0_col5 {
#   background-color: #167bb6;
#   color: #f1f1f1;
# }
# #T_685ac_row1_col0, #T_685ac_row5_col0 {
#   background-color: #73a9cf;
#   color: #f1f1f1;
# }
# #T_685ac_row1_col1, #T_685ac_row1_col2, #T_685ac_row1_col3, #T_685ac_row1_col4, #T_685ac_row1_col6, #T_685ac_row1_col7, #T_685ac_row1_col8, #T_685ac_row2_col1, #T_685ac_row2_col2, #T_685ac_row2_col3, #T_685ac_row2_col4, #T_685ac_row2_col6, #T_685ac_row2_col7, #T_685ac_row2_col8, #T_685ac_row3_col0, #T_685ac_row3_col1, #T_685ac_row3_col2, #T_685ac_row3_col3, #T_685ac_row3_col4, #T_685ac_row3_col5, #T_685ac_row3_col6, #T_685ac_row3_col7, #T_685ac_row3_col8, #T_685ac_row4_col1, #T_685ac_row4_col2, #T_685ac_row4_col3, #T_685ac_row4_col4, #T_685ac_row4_col6, #T_685ac_row4_col7, #T_685ac_row4_col8, #T_685ac_row5_col1, #T_685ac_row5_col2, #T_685ac_row5_col3, #T_685ac_row5_col4, #T_685ac_row5_col6, #T_685ac_row5_col7, #T_685ac_row5_col8, #T_685ac_row6_col1, #T_685ac_row6_col2, #T_685ac_row6_col3, #T_685ac_row6_col4, #T_685ac_row6_col6, #T_685ac_row6_col7, #T_685ac_row6_col8, #T_685ac_row7_col1, #T_685ac_row7_col2, #T_685ac_row7_col3, #T_685ac_row7_col4, #T_685ac_row7_col6, #T_685ac_row7_col7, #T_685ac_row7_col8 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_685ac_row1_col5, #T_685ac_row5_col5 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_685ac_row2_col0 {
#   background-color: #c4cbe3;
#   color: #000000;
# }
# #T_685ac_row2_col5 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_685ac_row4_col0 {
#   background-color: #d0d1e6;
#   color: #000000;
# }
# #T_685ac_row4_col5 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_685ac_row6_col0 {
#   background-color: #056faf;
#   color: #f1f1f1;
# }
# #T_685ac_row6_col5 {
#   background-color: #f5eef6;
#   color: #000000;
# }
# </style>
# <table id="T_685ac_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >id</th>
#       <th class="col_heading level0 col1" >Age</th>
#       <th class="col_heading level0 col2" >Driving_License</th>
#       <th class="col_heading level0 col3" >Region_Code</th>
#       <th class="col_heading level0 col4" >Previously_Insured</th>
#       <th class="col_heading level0 col5" >Annual_Premium</th>
#       <th class="col_heading level0 col6" >Policy_Sales_Channel</th>
#       <th class="col_heading level0 col7" >Vintage</th>
#       <th class="col_heading level0 col8" >Response</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_685ac_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_685ac_row0_col0" class="data row0 col0" >381109.000000</td>
#       <td id="T_685ac_row0_col1" class="data row0 col1" >381109.000000</td>
#       <td id="T_685ac_row0_col2" class="data row0 col2" >381109.000000</td>
#       <td id="T_685ac_row0_col3" class="data row0 col3" >381109.000000</td>
#       <td id="T_685ac_row0_col4" class="data row0 col4" >381109.000000</td>
#       <td id="T_685ac_row0_col5" class="data row0 col5" >381109.000000</td>
#       <td id="T_685ac_row0_col6" class="data row0 col6" >381109.000000</td>
#       <td id="T_685ac_row0_col7" class="data row0 col7" >381109.000000</td>
#       <td id="T_685ac_row0_col8" class="data row0 col8" >381109.000000</td>
#     </tr>
#     <tr>
#       <th id="T_685ac_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_685ac_row1_col0" class="data row1 col0" >190555.000000</td>
#       <td id="T_685ac_row1_col1" class="data row1 col1" >38.822584</td>
#       <td id="T_685ac_row1_col2" class="data row1 col2" >0.997869</td>
#       <td id="T_685ac_row1_col3" class="data row1 col3" >26.388807</td>
#       <td id="T_685ac_row1_col4" class="data row1 col4" >0.458210</td>
#       <td id="T_685ac_row1_col5" class="data row1 col5" >30564.389581</td>
#       <td id="T_685ac_row1_col6" class="data row1 col6" >112.034295</td>
#       <td id="T_685ac_row1_col7" class="data row1 col7" >154.347397</td>
#       <td id="T_685ac_row1_col8" class="data row1 col8" >0.122563</td>
#     </tr>
#     <tr>
#       <th id="T_685ac_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_685ac_row2_col0" class="data row2 col0" >110016.836208</td>
#       <td id="T_685ac_row2_col1" class="data row2 col1" >15.511611</td>
#       <td id="T_685ac_row2_col2" class="data row2 col2" >0.046110</td>
#       <td id="T_685ac_row2_col3" class="data row2 col3" >13.229888</td>
#       <td id="T_685ac_row2_col4" class="data row2 col4" >0.498251</td>
#       <td id="T_685ac_row2_col5" class="data row2 col5" >17213.155057</td>
#       <td id="T_685ac_row2_col6" class="data row2 col6" >54.203995</td>
#       <td id="T_685ac_row2_col7" class="data row2 col7" >83.671304</td>
#       <td id="T_685ac_row2_col8" class="data row2 col8" >0.327936</td>
#     </tr>
#     <tr>
#       <th id="T_685ac_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_685ac_row3_col0" class="data row3 col0" >1.000000</td>
#       <td id="T_685ac_row3_col1" class="data row3 col1" >20.000000</td>
#       <td id="T_685ac_row3_col2" class="data row3 col2" >0.000000</td>
#       <td id="T_685ac_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_685ac_row3_col4" class="data row3 col4" >0.000000</td>
#       <td id="T_685ac_row3_col5" class="data row3 col5" >2630.000000</td>
#       <td id="T_685ac_row3_col6" class="data row3 col6" >1.000000</td>
#       <td id="T_685ac_row3_col7" class="data row3 col7" >10.000000</td>
#       <td id="T_685ac_row3_col8" class="data row3 col8" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_685ac_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_685ac_row4_col0" class="data row4 col0" >95278.000000</td>
#       <td id="T_685ac_row4_col1" class="data row4 col1" >25.000000</td>
#       <td id="T_685ac_row4_col2" class="data row4 col2" >1.000000</td>
#       <td id="T_685ac_row4_col3" class="data row4 col3" >15.000000</td>
#       <td id="T_685ac_row4_col4" class="data row4 col4" >0.000000</td>
#       <td id="T_685ac_row4_col5" class="data row4 col5" >24405.000000</td>
#       <td id="T_685ac_row4_col6" class="data row4 col6" >29.000000</td>
#       <td id="T_685ac_row4_col7" class="data row4 col7" >82.000000</td>
#       <td id="T_685ac_row4_col8" class="data row4 col8" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_685ac_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_685ac_row5_col0" class="data row5 col0" >190555.000000</td>
#       <td id="T_685ac_row5_col1" class="data row5 col1" >36.000000</td>
#       <td id="T_685ac_row5_col2" class="data row5 col2" >1.000000</td>
#       <td id="T_685ac_row5_col3" class="data row5 col3" >28.000000</td>
#       <td id="T_685ac_row5_col4" class="data row5 col4" >0.000000</td>
#       <td id="T_685ac_row5_col5" class="data row5 col5" >31669.000000</td>
#       <td id="T_685ac_row5_col6" class="data row5 col6" >133.000000</td>
#       <td id="T_685ac_row5_col7" class="data row5 col7" >154.000000</td>
#       <td id="T_685ac_row5_col8" class="data row5 col8" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_685ac_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_685ac_row6_col0" class="data row6 col0" >285832.000000</td>
#       <td id="T_685ac_row6_col1" class="data row6 col1" >49.000000</td>
#       <td id="T_685ac_row6_col2" class="data row6 col2" >1.000000</td>
#       <td id="T_685ac_row6_col3" class="data row6 col3" >35.000000</td>
#       <td id="T_685ac_row6_col4" class="data row6 col4" >1.000000</td>
#       <td id="T_685ac_row6_col5" class="data row6 col5" >39400.000000</td>
#       <td id="T_685ac_row6_col6" class="data row6 col6" >152.000000</td>
#       <td id="T_685ac_row6_col7" class="data row6 col7" >227.000000</td>
#       <td id="T_685ac_row6_col8" class="data row6 col8" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_685ac_level

# %%
# describing the data for categoical features
df.describe(include = 'object')
# Out:
#         Gender Vehicle_Age Vehicle_Damage
# count   381109      381109         381109
# unique       2           3              2
# top       Male    1-2 Year            Yes
# freq    206089      200316         192413

# %% [markdown]
# #**Variables Description**

# %% [markdown]
# #id :	Unique ID for the customer
#
# #2. Gender	: Gender of the customer
#
# #3. Age :	Age of the customer
#
# #4. Driving_License	0 : Customer does not have DL, 1 : Customer already has DL
#
# #5. Region_Code :	Unique code for the region of the customer
#
# #6. Previously_Insured	: 1 : Customer already has Vehicle Insurance, 0 : Customer doesn't have Vehicle Insurance
#
# #7. Vehicle_Age :	Age of the Vehicle
#
# #8. Vehicle_Damage	 :1 : Customer got his/her vehicle damaged in the past. 0 : Customer didn't get his/her vehicle damaged in the past.
#
# #9. Annual_Premium	: The amount customer needs to pay as premium in the year
#
# #10. PolicySalesChannel :	Anonymized Code for the channel of outreaching to the customer ie. Different Agents, Over Mail, Over Phone, In Person,etc.
#
# #11. Vintage :	Number of Days, Customer has been associated with the company
#
# #12. Response :	1 : Customer is interested, 0 : Customer is not interested

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# checking for unique value in each column
df.nunique()
# Out:
# id                      381109
# Gender                       2
# Age                         66
# Driving_License              2
# Region_Code                 53
# Previously_Insured           2
# Vehicle_Age                  3
# Vehicle_Damage               2
# Annual_Premium           48838
# Policy_Sales_Channel       155
# Vintage                    290
# Response                     2
# dtype: int64

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# # **Exploratory Data Analysis**
#
# In this section, we will explore each feature in-depth, and hence this section is named EDA (Exploratory Data Analysis). This section will be helpful to understand the trend in features also we will be dealing with bi-variate analysis to understand what values are leading to success and failure. In order to visualize the data trends and distributions, we will be using matplotlib and seaborn libraries which will allow us to plot various plots for our data visualization.

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code
# Let's start with the taget feature i.e response column
# Exploring Response using pie plot and barplot

# creating two figures in a row for the visualization
fig , axes  = plt.subplots(1,2,figsize = (14,6 ))

# Plotting Pie plot to check the Response distribution percent wise
df['Response'].value_counts().plot.pie( autopct = '%.1f%%', explode = [0.04,0.04], startangle = 65, cmap = 'Accent', ax = axes[0])
axes[0].set_title('Percentage of each Response')

# plotting count plot for Response
sns.countplot(data = df , x = 'Response', palette = 'viridis', ax =  axes[1])
axes[1].set_title('count for each Response')


plt.tight_layout()

df['Response'].value_counts()
# Out:
# 0    334399
# 1     46710
# Name: Response, dtype: int64

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 2

# %% [markdown]
# ###  Analysis on Gender

# %%
# Chart - 2 visualization code
# Exploring Gender using pie plot and barplot

# creating two figures in a row for the visualization
fig , axes  = plt.subplots(1,2,figsize = (14,6 ))

# Plotting Pie plot to check the gender distribution percent wise
df['Gender'].value_counts().plot.pie( autopct = '%.1f%%', explode = [0.04,0.04], startangle = 110, cmap = 'Paired_r', ax = axes[0])
axes[0].set_title('Percentage of each gender')

# plotting count plot for gender
sns.countplot(data = df , x = 'Gender', palette = 'Paired', ax =  axes[1])
axes[1].set_title('count for each gender')


plt.tight_layout()

df['Gender'].value_counts()
# Out:
# Male      206089
# Female    175020
# Name: Gender, dtype: int64

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 3

# %% [markdown]
# # **Age**

# %%
# Chart - 3 visualization code
# understanding the Age feature distribution and it's effect on success/failure of insurance conversion 

# Defining the figure using subplots for two plots in one row
fig, axes = plt.subplots( 1,2 , figsize = (16,6))

# plotting distplot for Age column
sns.distplot( x= df['Age'], color= 'g', ax =axes[0])
axes[0].set_title('Age distribution')
axes[0].set_xlabel('Age')

# plotting distplot for Age and analyzing the effect on success/failure of insurance conversion
sns.distplot( x= df['Age'], color= 'r', ax =axes[1])
sns.distplot( x= df.Age[df['Response'] == 1], color= 'b', ax =axes[1])
axes[1].set_title('Age distribution Vs Response')
axes[1].set_xlabel('Age')

plt.show()
plt.tight_layout()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 4

# %% [markdown]
# # **Region code**

# %%
# Chart - 4 visualization code
# checking for numerically max value for region code
df['Region_Code'].max()
# Out:
# 52.0

# %%
# Analyzing region code feature and it's effect on response feature

# defining the figure for visualization
plt.figure(figsize = (15,5))

# no. of ticks on plot along x Axis
ticks = list(range(1,53))

# converting the datatype from flaot to int
df['Region_Code'] = df['Region_Code'].astype(int) 

# Plotting the reason code and it's effect on response in same plot
sns.histplot( x= df['Region_Code'], color = 'c', bins =52)
sns.histplot( x= df['Region_Code'][df['Response'] ==1 ],  color = 'r', bins =52)

plt.ylim(0,5000)
plt.xticks(ticks)
plt.title('Region Code Vs response')
plt.show()

# %%
# checking counts for DL
df['Driving_License'].value_counts()
# Out:
# 1    380297
# 0       812
# Name: Driving_License, dtype: int64

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 5

# %% [markdown]
# # **Vehicle age**

# %%
# Chart - 5 visualization code
# Analyzing Vehicle age distribution and it's effect on responses 

# defining the figures
fig , axes  = plt.subplots(1,2,figsize = (14,6 ))

# plotting pie chart on vehicle age distribution
df['Vehicle_Age'].value_counts().plot.pie( autopct = '%.1f%%', explode = [0.04,0.04, 0.04], startangle = 110, cmap = 'Paired', ax = axes[0])
axes[0].set_title('Vehicle disribution')

# plotting count plot along with effect on response
sns.histplot(data= df, x = 'Vehicle_Age', hue= df['Response'], palette='Paired_r')
axes[0].set_title('Vehicle disribution VS Response')

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 6

# %% [markdown]
# # **Vehicle damage**

# %%
# Chart - 6 visualization code
# Analysis on Vehicle damage and effect on response
plt.figure(figsize= (6,5))
sns.histplot(data = df, x= 'Vehicle_Damage', hue= df['Response'], palette = 'CMRmap_r')
plt.title('Vehicle Damage VS Response')

pd.DataFrame(df.groupby('Vehicle_Damage')['Response'].sum())
pd.DataFrame(df['Vehicle_Damage'].value_counts())
# Out:
#      Vehicle_Damage
# Yes          192413
# No           188696

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 7

# %% [markdown]
# # **Annual premium**

# %%
# Chart - 7 visualization code
# Analysis on Annual distribution along with response relation with annual premium

# defining figures
fig, axes = plt.subplots(2,1, figsize =( 15,12))

# plotting distplot for annual premium
sns.distplot( x= df['Annual_Premium'], ax = axes[0], bins = 100)
axes[0].set_title('Annual premium distribution')

# plotting hist plot and response distribution 
sns.histplot( x= df['Annual_Premium'], ax = axes[1], bins = 200, kde = True)
sns.histplot( x= df['Annual_Premium'][df['Response'] == 1], ax = axes[1], bins = 200, color = 'r', kde = True)
axes[1].set_xlim(0,200000)
axes[1].set_ylim(0,50000)
axes[1].set_title('Annual premium vs response')
# Out:
# Text(0.5, 1.0, 'Annual premium vs response')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 8

# %% [markdown]
# # **Policy sales channel**

# %%
# Chart - 8 visualization code
# converting the data type as int
df['Policy_Sales_Channel'] = df['Policy_Sales_Channel'].astype(int)

# %%
# plotting the relation between policy sales channel and responses
plt.figure(figsize = ( 15, 6))

# plotting the histogram plots for sales channel 
sns.histplot( x= df['Policy_Sales_Channel'], bins = 175)
sns.histplot( x= df['Policy_Sales_Channel'][df['Response'] == 1], bins = 175, color = 'r')

plt.ylim(0,50000)
plt.show()


# checking for the top 10 sales channel that produces the most no. of success 
sub_df1 = pd.DataFrame(df['Policy_Sales_Channel'].value_counts()).head(10).reset_index()
sub_df2 = pd.DataFrame(df.groupby('Policy_Sales_Channel')['Response'].sum()).reset_index()
sub_df2.rename(columns = {'Policy_Sales_Channel' : 'index'}, inplace = True)
top_channels = pd.merge(sub_df1 , sub_df2, on = 'index', how = 'left')
top_channels.rename(columns = {'index': 'Policy_Sales_Channel', 'Policy_Sales_Channel' : 'Counts', 'Response' : 'Response_1'  })
# Out:
#    Policy_Sales_Channel  Counts  Response_1
# 0                   152  134784        3858
# 1                    26   79700       15891
# 2                   124   73995       13996
# 3                   160   21779         475
# 4                   156   10661        2297
# 5                   122    9930        1720
# 6                   157    6684        1794
# 7                   154    5993        1474
# 8                   151    3885         122
# 9                   163    2893         880

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code
# Vintage distribution and success of insurance

plt.figure(figsize = ( 15, 6))

# Plotting the histograms for vintange and success of insurance along vintage 
sns.histplot( x= df['Vintage'], bins = 175)
sns.histplot( x= df['Vintage'][df['Response'] == 1], bins = 175, color = 'r')

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code
# Analysis on previously insured damage and effect on response
df['Previously_Insured'].astype(int)
plt.figure(figsize= (6,5))
sns.countplot(data = df, x= 'Previously_Insured', hue= df['Response'], palette = 'Paired')
plt.title('Previously_insured VS Response')

pd.DataFrame(df.groupby('Previously_Insured')['Response'].sum())
pd.DataFrame(df['Previously_Insured'].value_counts())
# Out:
#    Previously_Insured
# 0              206481
# 1              174628

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 11- Correlation Heatmap

# %%
# Correlation Heatmap visualization code
# Plotting heatmap to look at the correlation of features
plt.figure(figsize = (14,12))
sns.heatmap(df.corr(), annot = True,  cmap = 'viridis')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 12 - Pair Plot

# %%
# Pair Plot visualization code
# plotting pairplot which will give overview of  all the numeric features and responses in 1 plot but surely
sns.pairplot(df[['Age', 'Annual_Premium', 'Policy_Sales_Channel', 'Vintage', 'Response']], hue= 'Response')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ## ***5. Hypothesis Testing***

# %% [markdown]
# ### Based on your chart experiments, define three hypothetical statements from the dataset. In the next three questions, perform hypothesis testing to obtain final conclusion about the statements through your code and statistical testing.

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### Hypothetical Statement - 1

# %% [markdown]
# #### 1. State Your research hypothesis as a null hypothesis and alternate hypothesis.

# %% [markdown]
# Answer Here.

# %% [markdown]
# #### 2. Perform an appropriate statistical test.

# %%
# Perform Statistical Test to obtain P-Value

# %% [markdown]
# ##### Which statistical test have you done to obtain P-Value?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Why did you choose the specific statistical test?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### Hypothetical Statement - 2

# %% [markdown]
# #### 1. State Your research hypothesis as a null hypothesis and alternate hypothesis.

# %% [markdown]
# Answer Here.

# %% [markdown]
# #### 2. Perform an appropriate statistical test.

# %%
# Perform Statistical Test to obtain P-Value

# %% [markdown]
# ##### Which statistical test have you done to obtain P-Value?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Why did you choose the specific statistical test?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### Hypothetical Statement - 3

# %% [markdown]
# #### 1. State Your research hypothesis as a null hypothesis and alternate hypothesis.

# %% [markdown]
# Answer Here.

# %% [markdown]
# #### 2. Perform an appropriate statistical test.

# %%
# Perform Statistical Test to obtain P-Value

# %% [markdown]
# ##### Which statistical test have you done to obtain P-Value?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Why did you choose the specific statistical test?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ## ***6. Feature Engineering & Data Pre-processing***

# %% [markdown]
# ### 1. Handling Missing Values

# %%
# Handling Missing Values & Missing Value Imputation
# checking for null values
df.isnull().sum()
# Out:
# id                      0
# Gender                  0
# Age                     0
# Driving_License         0
# Region_Code             0
# Previously_Insured      0
# Vehicle_Age             0
# Vehicle_Damage          0
# Annual_Premium          0
# Policy_Sales_Channel    0
# Vintage                 0
# Response                0
# dtype: int64

# %% [markdown]
# #### What all missing value imputation techniques have you used and why did you use those techniques?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 2. Handling Outliers

# %%
df['Annual_Premium'].describe()
# Out:
# count   381,109.00
# mean     30,564.39
# std      17,213.16
# min       2,630.00
# 25%      24,405.00
# 50%      31,669.00
# 75%      39,400.00
# max     540,165.00
# Name: Annual_Premium, dtype: float64

# %%
# Handling Outliers & Outlier treatments
plt.figure(figsize=(15,10))

plt.ylabel('Annual_Premium')
sns.boxplot(x=np.sqrt(df['Annual_Premium']))
plt.show()

# %% [markdown]
# ##### What all outlier treatment techniques have you used and why did you use those techniques?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 3. Categorical Encoding

# %%
# Encode your categorical columns
# Encode your categorical columns
categorical_features= df.select_dtypes(include='object')

# %%
categorical_features
# Out:
#         Gender Vehicle_Age Vehicle_Damage
# 0         Male   > 2 Years            Yes
# 1         Male    1-2 Year             No
# 2         Male   > 2 Years            Yes
# 3         Male    < 1 Year             No
# 4       Female    < 1 Year             No
# ...        ...         ...            ...
# 381104    Male    1-2 Year             No
# 381105    Male    < 1 Year             No
# 381106    Male    < 1 Year             No
# 381107  Female   > 2 Years            Yes
# 381108    Male    1-2 Year             No
#
# [381109 rows x 3 columns]

# %%
#ploting Box plot to visualize and trying to get information from plot
for col in categorical_features:
  plt.figure(figsize=(10,8))
  sns.boxplot(x=df[col],y=df["Annual_Premium"])
  plt.show()

# %% [markdown]
# #### What all categorical encoding techniques have you used & why did you use those techniques?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 4. Textual Data Preprocessing
# (It's mandatory for textual dataset i.e., NLP, Sentiment Analysis, Text Clustering etc.)

# %% [markdown]
# #### 1. Expand Contraction

# %%
# Expand Contraction

# %% [markdown]
# #### 2. Lower Casing

# %%
# Lower Casing

# %% [markdown]
# #### 3. Removing Punctuations

# %%
# Remove Punctuations

# %% [markdown]
# #### 4. Removing URLs & Removing words and digits contain digits.

# %%
# Remove URLs & Remove words and digits contain digits

# %% [markdown]
# #### 5. Removing Stopwords & Removing White spaces

# %%
# Remove Stopwords

# %%
# Remove White spaces

# %% [markdown]
# #### 6. Rephrase Text

# %%
# Rephrase Text

# %% [markdown]
# #### 7. Tokenization

# %%
# Tokenization

# %% [markdown]
# #### 8. Text Normalization

# %%
# Normalizing Text (i.e., Stemming, Lemmatization etc.)

# %% [markdown]
# ##### Which text normalization technique have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# #### 9. Part of speech tagging

# %%
# POS Taging

# %% [markdown]
# #### 10. Text Vectorization

# %%
# Vectorizing Text

# %% [markdown]
# ##### Which text vectorization technique have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 4. Feature Manipulation & Selection

# %% [markdown]
# #### 1. Feature Manipulation

# %%
# Manipulate Features to minimize feature correlation and create new 
# Checking the first five observation of the dataset we have to deal with.
df.head()
# Out:
#    id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0   1    Male   44                1           28                   0
# 1   2    Male   76                1            3                   0
# 2   3    Male   47                1           28                   0
# 3   4    Male   21                1           11                   1
# 4   5  Female   29                1           41                   1
#
#   Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  \
# 0   > 2 Years            Yes       40,454.00                    26      217
# 1    1-2 Year             No       33,536.00                    26      183
# 2   > 2 Years            Yes       38,294.00                    26       27
# 3    < 1 Year             No       28,619.00                   152      203
# 4    < 1 Year             No       27,496.00                   152       39
#
#    Response
# 0         1
# 1         0
# 2         1
# 3         0
# 4         0

# %%
# Extracting date, month and year from Date feature
df["Driving_Licence"]= df["Gender"].dt.Driving_Licence
df["Previously_Insured"]= df["Gender"].dt.Previously_Insured
df["Response"]= df["Gender"].dt.Response
df["Vintage"]= df["Gender"].dt.Vintage
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-55-d7923f0c3a50> in <module>
#       1 # Extracting date, month and year from Date feature
# ----> 2 df["Driving_Licence"]= df["Gender"].dt.Driving_Licence
#       3 df["Previously_Insured"]= df["Gender"].dt.Previously_Insured
#       4 df["Response"]= df["Gender"].dt.Response
#       5 df["Vintage"]= df["Gender"].dt.Vintage
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     179             # we're accessing the attribute of the class, i.e., Dataset.geo
#     180             return self._accessor
# --> 181         accessor_obj = self._accessor(obj)
#     182         # Replace the property with the accessor object. Inspired by:
#     183         # https://www.pydanny.com/cached-property.html
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexes/accessors.py in __new__(cls, data)
#     504             return PeriodProperties(data, orig)
#     505
# --> 506         raise AttributeError("Can only use .dt accessor with datetimelike values")
#
# AttributeError: Can only use .dt accessor with datetimelike values

# %% [markdown]
# #### 2. Feature Selection

# %%
# Select your features wisely to avoid overfitting
# Let's see how Rented Bike Count and other features are related
for col in df.describe().columns.tolist():
    fig = plt.figure(figsize=(9, 6))
    ax = fig.gca()
    feature = df[col]
    label = df['id']
    correlation = feature.corr(label)
    sns.scatterplot(x=feature, y=label, color="Orange")
    plt.xlabel(col)
    plt.ylabel('id')
    ax.set_title('id vs ' + col + '- correlation: ' + str(correlation))
    z = np.polyfit(df[col], df['id'], 1)
    y_hat = np.poly1d(z)(df[col])
    plt.plot(df[col], y_hat, "r--", lw=1)
    plt.show()

# %% [markdown]
# ##### What all feature selection methods have you used  and why?

# %%
# Select your features wisely to avoid overfitting
plt.figure(figsize=(20,15))
sns.heatmap(abs(round(df.corr(),3)), annot=True, cmap=plt.cm.CMRmap)

# %% [markdown]
# # Answer

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

def calc_vif(x):

    # Calculating VIF
    vif = pd.DataFrame()
    vif["variables"] = x.columns
    vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(x.shape[1])]

    return(vif)

# %%
calc_vif(x.select_dtypes(include=['float','int']))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-66-b4bb81fbf926> in <module>
# ----> 1 calc_vif(x.select_dtypes(include=['float','int']))
#
# NameError: name 'x' is not defined

# %% [markdown]
# ##### Which all features you found important and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 5. Data Transformation

# %% [markdown]
# #### Do you think that your data needs to be transformed? If yes, which transformation have you used. Explain Why?

# %%
# Transform Your data

# %% [markdown]
# ### 6. Data Scaling

# %%
# Scaling your data

# %% [markdown]
# ##### Which method have you used to scale you data and why?

# %% [markdown]
# ### 7. Dimesionality Reduction

# %% [markdown]
# ##### Do you think that dimensionality reduction is needed? Explain Why?

# %% [markdown]
# Answer Here.

# %%
# DImensionality Reduction (If needed)

# %% [markdown]
# ##### Which dimensionality reduction technique have you used and why? (If dimensionality reduction done on dataset.)

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 8. Data Splitting

# %%
# Split your data to train and test. Choose Splitting ratio wisely.

# %% [markdown]
# ##### What data splitting ratio have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 9. Handling Imbalanced Dataset

# %% [markdown]
# ##### Do you think the dataset is imbalanced? Explain Why.

# %% [markdown]
# Answer Here.

# %%
# Handling Imbalanced Dataset (If needed)

# %% [markdown]
# ##### What technique did you use to handle the imbalance dataset and why? (If needed to be balanced)

# %% [markdown]
# Answer Here.

# %% [markdown]
# ## ***7. ML Model Implementation***

# %% [markdown]
# ### ML Model - 1

# %%
# ML Model - 1 Implementation

# Fit the Algorithm

# Predict on the model

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# Visualizing evaluation Metric Score chart

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
# ML Model - 1 Implementation with hyperparameter optimization techniques (i.e., GridSearch CV, RandomSearch CV, Bayesian Optimization etc.)

# Fit the Algorithm

# Predict on the model

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### ML Model - 2

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# Visualizing evaluation Metric Score chart

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
# ML Model - 1 Implementation with hyperparameter optimization techniques (i.e., GridSearch CV, RandomSearch CV, Bayesian Optimization etc.)

# Fit the Algorithm

# Predict on the model

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# Answer Here.

# %% [markdown]
# #### 3. Explain each evaluation metric's indication towards business and the business impact pf the ML model used.

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### ML Model - 3

# %%
# ML Model - 3 Implementation

# Fit the Algorithm

# Predict on the model

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# Visualizing evaluation Metric Score chart

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
# ML Model - 3 Implementation with hyperparameter optimization techniques (i.e., GridSearch CV, RandomSearch CV, Bayesian Optimization etc.)

# Fit the Algorithm

# Predict on the model

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 1. Which Evaluation metrics did you consider for a positive business impact and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 2. Which ML model did you choose from the above created models as your final prediction model and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 3. Explain the model which you have used and the feature importance using any model explainability tool?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ## ***8.*** ***Future Work (Optional)***

# %% [markdown]
# ### 1. Save the best performing ml model in a pickle file or joblib file format for deployment process.

# %%
# Save the File

# %% [markdown]
# ### 2. Again Load the saved model file and try to predict unseen data for a sanity check.

# %%
# Load the File and predict unseen data.

# %% [markdown]
# ### ***Congrats! Your model is successfully created and ready for deployment on a live server for a real user interaction !!!***

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Write the conclusion here.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your Machine Learning Capstone Project !!!***
